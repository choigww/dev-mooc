# %%
import pandas as pd
import matplotlib.pyplot as plt
import collections
from wordcloud import WordCloud

# %%
df = pd.read_csv('./csv/cleaned_movie_review_2019_3.csv', index_col=0)

# %%
words = df['cleaned_review'][3].split(' ')
worddict = collections.Counter(words)

# %%
stop_words = ['배우', '영화', '감독', '출연', '리뷰', '보기', '연출', '방식', '방법', '가장', '정말', '생각']

# %%
wordcloud_img = WordCloud(
    background_color = 'white',
    max_words = 2000,
    font_path="./font/AppleGothic.ttf",
    stopwords=stop_words
).generate(df['cleaned_review'][3])

# %%
plt.figure(figsize=(8,8))
plt.imshow(wordcloud_img, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
okt = Okt()
tokens = okt(df['cleaned_review'][3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-3758da328b70> in <module>
# ----> 1 okt = Okt()
#       2 tokens = okt(df['cleaned_review'][3])
#
# NameError: name 'Okt' is not defined

# %%
worddict = collections.Counter(words)
